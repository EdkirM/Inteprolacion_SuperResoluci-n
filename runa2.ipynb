# %%
# import os, argparse
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# import tensorflow as tf

# import source.neuralnet as nn
# import source.datamanager as dman
# import source.tf_process as tfp
# import source.stamper as stamper
# stamper.print_stamp()

# def main():

#     srnet = nn.SRNET()

#     dataset = dman.DataSet()

#     sess = tf.compat.v1.InteractiveSession()
#     sess.run(tf.compat.v1.global_variables_initializer())
#     saver = tf.compat.v1.train.Saver()

#     tfp.training(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset, epochs=FLAGS.epoch, batch_size=FLAGS.batch)
#     tfp.validation(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset)

# if __name__ == '__main__':

#     parser = argparse.ArgumentParser()
#     parser.add_argument('--epoch', type=int, default=5000, help='-')
#     parser.add_argument('--batch', type=int, default=16, help='-')

#     FLAGS, unparsed = parser.parse_known_args()

#     main()
# Out:
# Implementation by...
#   _ _ __ __ _ _ ____   _ _ _ _ __ __ _ _
#  | | | _|  \ \ |  __| | | | | | _|  \ \ |
#  |  / _| ()|   | |_ | |   |  / _| ()|   |  _
# |__/____|__/_|_|____| |_|_/_/____|__/_|_| (_)
#
# https://github.com/YeongHyeon
#
# ** Initialize Super-Resolution Network
# WARNING:tensorflow:From d:\Descargas 2\Super-Resolution_CNN-master\Super-Resolution_CNN-master\source\neuralnet.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 33
#      29 parser.add_argument('--batch', type=int, default=16, help='-')
#      31 FLAGS, unparsed = parser.parse_known_args()
# ---> 33 main()
#
# Cell In[1], line 14, in main()
#      12 def main():
# ---> 14     srnet = nn.SRNET()
#      16     dataset = dman.DataSet()
#      18     sess = tf.compat.v1.InteractiveSession()
#
# File d:\Descargas 2\Super-Resolution_CNN-master\Super-Resolution_CNN-master\source\neuralnet.py:13, in SRNET.__init__(self)
#       9 def __init__(self):
#      11     print("\n** Initialize Super-Resolution Network")
# ---> 13     self.inputs = tf.compat.v1.placeholder(tf.float32, [None, None, None, None])
#      14     self.outputs = tf.compat.v1.placeholder(tf.float32, [None, None, None, None])
#      16     self.channel = 3
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\array_ops.py:2991, in placeholder(dtype, shape, name)
#    2944 """Inserts a placeholder for a tensor that will be always fed.
#    2945
#    2946 **Important**: This tensor will produce an error if evaluated. Its value must
#    (...)
#    2988 @end_compatibility
#    2989 """
#    2990 if context.executing_eagerly():
# -> 2991   raise RuntimeError("tf.placeholder() is not compatible with "
#    2992                      "eager execution.")
#    2994 return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#
# RuntimeError: tf.placeholder() is not compatible with eager execution.

# %%
import tensorflow as tf

# Desactivar eager execution
tf.compat.v1.disable_eager_execution()

# Luego, importar otros módulos y continuar con tu script
import os
import argparse
import source.neuralnet as nn
import source.datamanager as dman
import source.tf_process as tfp
import source.stamper as stamper
stamper.print_stamp()

def main():
    srnet = nn.SRNET()
    dataset = dman.DataSet()

    sess = tf.compat.v1.InteractiveSession()
    sess.run(tf.compat.v1.global_variables_initializer())
    saver = tf.compat.v1.train.Saver()

    tfp.training(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset, epochs=FLAGS.epoch, batch_size=FLAGS.batch)
    tfp.validation(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset)

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--epoch', type=int, default=5000, help='-')
    parser.add_argument('--batch', type=int, default=16, help='-')

    FLAGS, unparsed = parser.parse_known_args()

    main()
# Out:
# Implementation by...
#   _ _ __ __ _ _ ____   _ _ _ _ __ __ _ _
#  | | | _|  \ \ |  __| | | | | | _|  \ \ |
#  |  / _| ()|   | |_ | |   |  / _| ()|   |  _
# |__/____|__/_|_|____| |_|_/_/____|__/_|_| (_)
#
# https://github.com/YeongHyeon
#
# ** Initialize Super-Resolution Network
# Patch Extraction filter : (9, 9, 3, 64)
# Non-linear mapping      : (1, 1, 64, 32)
# Reconstruction          : (5, 5, 32, 3)
# WARNING:tensorflow:From d:\Descargas 2\Super-Resolution_CNN-master\Super-Resolution_CNN-master\source\neuralnet.py:48: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From d:\Descargas 2\Super-Resolution_CNN-master\Super-Resolution_CNN-master\source\neuralnet.py:68: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
#
# Training SRCNN to 5000 epochs
# Epoch [0 / 5000] | Loss: 1332.808105  PSNR: 5.625799
# Epoch [1 / 5000] | Loss: 657.058716  PSNR: 6.126352
# Epoch [2 / 5000] | Loss: 967.121033  PSNR: 6.448588
# Epoch [3 / 5000] | Loss: 513.042419  PSNR: 6.061907
# Epoch [4 / 5000] | Loss: 338.513336  PSNR: 6.612658
# Epoch [5 / 5000] | Loss: 1086.144897  PSNR: 7.781282
# Epoch [6 / 5000] | Loss: 293.931061  PSNR: 7.939683
# Epoch [7 / 5000] | Loss: 399.768463  PSNR: 4.986480
# Epoch [8 / 5000] | Loss: 549.047363  PSNR: 7.132095
# Epoch [9 / 5000] | Loss: 469.623749  PSNR: 5.435947
# Epoch [10 / 5000] | Loss: 1106.296631  PSNR: 6.301270
# Epoch [11 / 5000] | Loss: 476.731293  PSNR: 6.699500
# Epoch [12 / 5000] | Loss: 380.029053  PSNR: 5.426315
# Epoch [13 / 5000] | Loss: 397.117096  PSNR: 5.567558
# Epoch [14 / 5000] | Loss: 1115.871094  PSNR: 7.168870
# Epoch [15 / 5000] | Loss: 1045.235474  PSNR: 6.794419
# Epoch [16 / 5000] | Loss: 337.316406  PSNR: 7.658000
# Epoch [17 / 5000] | Loss: 359.547241  PSNR: 6.114377
# Epoch [18 / 5000] | Loss: 529.435608  PSNR: 7.422255
# Epoch [19 / 5000] | Loss: 351.816925  PSNR: 6.096316
# Epoch [20 / 5000] | Loss: 324.957336  PSNR: 7.566300
# Epoch [21 / 5000] | Loss: 323.389435  PSNR: 7.608311
# Epoch [22 / 5000] | Loss: 343.681000  PSNR: 6.299541
# Epoch [23 / 5000] | Loss: 1012.163757  PSNR: 8.016136
# Epoch [24 / 5000] | Loss: 887.263550  PSNR: 9.537984
# Epoch [25 / 5000] | Loss: 368.219574  PSNR: 7.229418
# Epoch [26 / 5000] | Loss: 982.999939  PSNR: 8.270082
# Epoch [27 / 5000] | Loss: 490.239441  PSNR: 8.090354
# Epoch [28 / 5000] | Loss: 964.610596  PSNR: 8.434111
# Epoch [29 / 5000] | Loss: 650.361938  PSNR: 6.936199
# Epoch [30 / 5000] | Loss: 681.279541  PSNR: 10.071617
# Epoch [31 / 5000] | Loss: 830.728943  PSNR: 10.109850
# Epoch [32 / 5000] | Loss: 336.429871  PSNR: 8.163806
# Epoch [260 / 5000] | Loss: 591.442017  PSNR: 12.682906
# Epoch [261 / 5000] | Loss: 406.738159  PSNR: 11.013002
# Epoch [262 / 5000] | Loss: 227.821869  PSNR: 10.577878
# Epoch [263 / 5000] | Loss: 732.586060  PSNR: 11.201863
# Epoch [264 / 5000] | Loss: 727.651245  PSNR: 11.260571
# Epoch [265 / 5000] | Loss: 723.190369  PSNR: 11.313984
# Epoch [266 / 5000] | Loss: 257.550354  PSNR: 10.653707
# Epoch [267 / 5000] | Loss: 215.598007  PSNR: 9.693508
# Epoch [268 / 5000] | Loss: 190.394226  PSNR: 11.429576
# Epoch [269 / 5000] | Loss: 719.218994  PSNR: 11.361814
# Epoch [270 / 5000] | Loss: 229.800232  PSNR: 12.418417
# Epoch [271 / 5000] | Loss: 581.986877  PSNR: 12.822886
# Epoch [272 / 5000] | Loss: 581.298950  PSNR: 11.890711
# Epoch [273 / 5000] | Loss: 249.519089  PSNR: 10.928874
# Epoch [274 / 5000] | Loss: 176.476715  PSNR: 13.617807
# Epoch [275 / 5000] | Loss: 218.940048  PSNR: 12.838921
# Epoch [276 / 5000] | Loss: 217.008896  PSNR: 9.728287
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 33
#      29 parser.add_argument('--batch', type=int, default=16, help='-')
#      31 FLAGS, unparsed = parser.parse_known_args()
# ---> 33 main()
#
# Cell In[2], line 23, in main()
#      20 sess.run(tf.compat.v1.global_variables_initializer())
#      21 saver = tf.compat.v1.train.Saver()
# ---> 23 tfp.training(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset, epochs=FLAGS.epoch, batch_size=FLAGS.batch)
#      24 tfp.validation(sess=sess, neuralnet=srnet, saver=saver, dataset=dataset)
#
# File d:\Descargas 2\Super-Resolution_CNN-master\Super-Resolution_CNN-master\source\tf_process.py:78, in training(sess, neuralnet, saver, dataset, epochs, batch_size)
#      76 plt.imshow(img_ground)
#      77 plt.tight_layout(pad=1, w_pad=1, h_pad=1)
# ---> 78 plt.savefig("%s/training/%09d_psnr_%d.png" %(PACK_PATH, epoch, int(tmp_psnr)))
#      79 plt.close()
#      81 """static img(test)"""
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:563, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     560     alpha = self._get_scalar_alpha()
#     561     output_alpha = _resample(  # resample alpha channel
#     562         self, A[..., 3], out_shape, t, alpha=alpha)
# --> 563     output = _resample(  # resample rgb channels
#     564         self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     565     output[..., 3] = output_alpha  # recombine rgb and alpha
#     567 # output is now either a 2D array of normed (int or float) data
#     568 # or an RGBA array of re-sampled input
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:205, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     203     else:
#     204         interpolation = 'hanning'
# --> 205 out = np.zeros(out_shape + data.shape[2:], data.dtype)  # 2D->2D, 3D->3D.
#     206 if resample is None:
#     207     resample = image_obj.get_resample()
#
# MemoryError: Unable to allocate 129. MiB for an array with shape (3415, 2468, 4) and data type float32
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2155     # we do this instead of `self.figure.draw_without_rendering`
#    2156     # so that we can inject the orientation
#    2157     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158         self.figure.draw(renderer)
#    2159 if bbox_inches:
#    2160     if bbox_inches == "tight":
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:649, in _ImageBase.draw(self, renderer, *args, **kwargs)
#     647         renderer.draw_image(gc, l, b, im, trans)
#     648 else:
# --> 649     im, l, b, trans = self.make_image(
#     650         renderer, renderer.get_image_magnification())
#     651     if im is not None:
#     652         renderer.draw_image(gc, l, b, im)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:939, in AxesImage.make_image(self, renderer, magnification, unsampled)
#     936 transformed_bbox = TransformedBbox(bbox, trans)
#     937 clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     938         else self.figure.bbox)
# --> 939 return self._make_image(self._A, bbox, transformed_bbox, clip,
#     940                         magnification, unsampled=unsampled)
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:561, in _ImageBase._make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     559     A = _rgb_to_rgba(A)
#     560 alpha = self._get_scalar_alpha()
# --> 561 output_alpha = _resample(  # resample alpha channel
#     562     self, A[..., 3], out_shape, t, alpha=alpha)
#     563 output = _resample(  # resample rgb channels
#     564     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     565 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# File c:\Users\urina\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:205, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     203     else:
#     204         interpolation = 'hanning'
# --> 205 out = np.zeros(out_shape + data.shape[2:], data.dtype)  # 2D->2D, 3D->3D.
#     206 if resample is None:
#     207     resample = image_obj.get_resample()
#
# MemoryError: Unable to allocate 32.2 MiB for an array with shape (3415, 2468) and data type float32
